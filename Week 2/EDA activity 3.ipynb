# %%
#import pandas as pd

# %%
#pd.read_csv("Data_Marketing_Customer_Analysis_Round3 (2).csv")
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 0          central                     4809       no     basic   college
# 1      west region                     2228       no     basic   college
# 2             east                    14947       no     basic  bachelor
# 3       north west                    22332      yes  extended   college
# 4       north west                     9025       no   premium  bachelor
# ...            ...                      ...      ...       ...       ...
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688      central                     6857       no     basic  bachelor
#
#       effective_to_date month employment_status gender  income  ...  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def load_original_data():
    file = pd.read_csv("Data_Marketing_Customer_Analysis_Round3 (2).csv")
    return file

# %%
marketing_df = load_original_data()

# %%
marketing_df.reset_index(drop =True,inplace=True)

# %%
marketing_df
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 0          central                     4809       no     basic   college
# 1      west region                     2228       no     basic   college
# 2             east                    14947       no     basic  bachelor
# 3       north west                    22332      yes  extended   college
# 4       north west                     9025       no   premium  bachelor
# ...            ...                      ...      ...       ...       ...
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688      central                     6857       no     basic  bachelor
#
#       effective_to_date month employment_status gender  income  ...  \
# ...

# %%
nulls_df = pd.DataFrame(round(marketing_df.isna().sum()/len(marketing_df),4)*100)
nulls_df = nulls_df.reset_index()
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                       header_name  percent_nulls
# 0                          region            0.0
# 1         customer_lifetime_value            0.0
# 2                        response            0.0
# 3                        coverage            0.0
# 4                       education            0.0
# 5               effective_to_date            0.0
# 6                           month            0.0
# 7               employment_status            0.0
# 8                          gender            0.0
# 9                          income            0.0
# 10                  location_code            0.0
# 11                 marital_status            0.0
# 12           monthly_premium_auto            0.0
# 13        months_since_last_claim            0.0
# 14  months_since_policy_inception            0.0
# 15      number_of_open_complaints            0.0
# 16             number_of_policies            0.0
# 17                    policy_type            0.0
# ...
