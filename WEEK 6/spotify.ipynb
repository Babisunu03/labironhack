# %%
import config

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials



sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
playlist = sp.user_playlist_tracks("Spotify", "37i9dQZF1DX05r4Oy3Ln97",market = "GB")

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX05r4Oy3Ln97/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2023-09-08T11:06:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2mLA48B366zkELXYx7hcDN'},
#        'href': 'https://api.spotify.com/v1/artists/2mLA48B366zkELXYx7hcDN',
#        'id': '2mLA48B366zkELXYx7hcDN',
#        'name': 'Peggy Gou',
#        'type': 'artist',
#        'uri': 'spotify:artist:2mLA48B366zkELXYx7hcDN'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2LVDNOUUy2g8517ZEtQIcK'},
#      'href': 'https://api.spotify.com/v1/albums/2LVDNOUUy2g8517ZEtQIcK',
# ...

# %%
type(playlist)
# Out:
# dict

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist["items"][0]
# Out:
# {'added_at': '2023-09-08T11:06:41Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2mLA48B366zkELXYx7hcDN'},
#      'href': 'https://api.spotify.com/v1/artists/2mLA48B366zkELXYx7hcDN',
#      'id': '2mLA48B366zkELXYx7hcDN',
#      'name': 'Peggy Gou',
#      'type': 'artist',
#      'uri': 'spotify:artist:2mLA48B366zkELXYx7hcDN'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2LVDNOUUy2g8517ZEtQIcK'},
#    'href': 'https://api.spotify.com/v1/albums/2LVDNOUUy2g8517ZEtQIcK',
#    'id': '2LVDNOUUy2g8517ZEtQIcK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2739a8459318ff1a68ecfd74522',
#      'width': 640},
# ...

# %%
playlist["items"][0]["track"]["id"]
# Out:
# '23RoR84KodL5HWvUTneQ1w'

# %%
import pprint

# %%
pprint.pprint(playlist)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX05r4Oy3Ln97/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2023-09-08T11:06:41Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'single',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2mLA48B366zkELXYx7hcDN'},
#                                              'href': 'https://api.spotify.com/v1/artists/2mLA48B366zkELXYx7hcDN',
#                                              'id': '2mLA48B366zkELXYx7hcDN',
# ...

# %%
playlist["items"][0]["track"]["id"]
# Out:
# '23RoR84KodL5HWvUTneQ1w'

# %%
pprint.pprint(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 pprint.pprint(results)
#
# NameError: name 'results' is not defined

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
my_playlist =get_playlist_tracks('spotify','37i9dQZF1DX05r4Oy3Ln97')

# %%
my_playlist[0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
my_playlist[0]
# Out:
# {'added_at': '2023-09-08T11:06:41Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2mLA48B366zkELXYx7hcDN'},
#      'href': 'https://api.spotify.com/v1/artists/2mLA48B366zkELXYx7hcDN',
#      'id': '2mLA48B366zkELXYx7hcDN',
#      'name': 'Peggy Gou',
#      'type': 'artist',
#      'uri': 'spotify:artist:2mLA48B366zkELXYx7hcDN'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2LVDNOUUy2g8517ZEtQIcK'},
#    'href': 'https://api.spotify.com/v1/albums/2LVDNOUUy2g8517ZEtQIcK',
#    'id': '2LVDNOUUy2g8517ZEtQIcK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2739a8459318ff1a68ecfd74522',
#      'width': 640},
# ...

# %%
my_playlist_id_list = []
for i in my_playlist:
    my_playlist_id_list.append(i['track']['id'])

# %%
audio_list =[]
for i in my_playlist_id_list:
    audio_list.append(sp.audio_features(i)[0])
audio_list
# Out:
# [{'danceability': 0.671,
#   'energy': 0.876,
#   'key': 7,
#   'loudness': -5.681,
#   'mode': 0,
#   'speechiness': 0.0352,
#   'acousticness': 0.12,
#   'instrumentalness': 0.188,
#   'liveness': 0.0823,
#   'valence': 0.964,
#   'tempo': 129.998,
#   'type': 'audio_features',
#   'id': '23RoR84KodL5HWvUTneQ1w',
#   'uri': 'spotify:track:23RoR84KodL5HWvUTneQ1w',
#   'track_href': 'https://api.spotify.com/v1/tracks/23RoR84KodL5HWvUTneQ1w',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/23RoR84KodL5HWvUTneQ1w',
#   'duration_ms': 231545,
#   'time_signature': 4},
#  {'danceability': 0.735,
#   'energy': 0.651,
#   'key': 7,
#   'loudness': -9.25,
#   'mode': 0,
#   'speechiness': 0.112,
#   'acousticness': 0.329,
#   'instrumentalness': 0.000205,
#   'liveness': 0.131,
#   'valence': 0.476,
#   'tempo': 127.07,
#   'type': 'audio_features',
#   'id': '1ACFweuuvf6MHtptObgreR',
#   'uri': 'spotify:track:1ACFweuuvf6MHtptObgreR',
# ...

# %%
import pandas as pd

# %%
my_playlist_df = pd.DataFrame(audio_list)
my_playlist_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.671   0.876    7    -5.681     0       0.0352      0.120000
# 1          0.735   0.651    7    -9.250     0       0.1120      0.329000
# 2          0.747   0.616    3    -9.760     0       0.0324      0.176000
# 3          0.578   0.912    1    -3.929     1       0.1140      0.016600
# 4          0.789   0.435    2    -9.506     0       0.1490      0.691000
# 5          0.669   0.718    9    -7.782     0       0.0438      0.088600
# 6          0.772   0.882    1    -5.242     0       0.0589      0.006060
# 7          0.729   0.836    8    -4.312     1       0.0462      0.156000
# 8          0.762   0.942    9    -6.432     0       0.0380      0.586000
# 9          0.700   0.748    9    -8.160     0       0.0771      0.226000
# 10         0.772   0.882    9    -3.897     0       0.2140      0.047100
# 11         0.654   0.898    7    -5.964     1       0.0413      0.084400
# ...

# %%
playlist["items"][0]["track"]["id"]
# Out:
# '23RoR84KodL5HWvUTneQ1w'

# %%
playlist["items"][1]["track"]["id"]
# Out:
# '1ACFweuuvf6MHtptObgreR'

# %%
my_playlist_id_list
# Out:
# ['23RoR84KodL5HWvUTneQ1w',
#  '1ACFweuuvf6MHtptObgreR',
#  '5u4hhtZ7f4rWkMZEZcTKrH',
#  '40SBS57su9xLiE1WqkXOVr',
#  '05GvwwTLLID738BbKN1ze0',
#  '14VthBnru6kiREQUYAuNSL',
#  '3fpKdubElctX8ZrwA548Mj',
#  '6yv0ZjBlZy2oRFq7jAis2C',
#  '4SnuG111QPmgwRmlwhJ4Mg',
#  '5985LToyqbVWWNczsD9g5N',
#  '0skgJbXMM4sPRwSKXvO2id',
#  '5u8Y0lAUlBLwuhpXSDUGf4',
#  '33tYADyL2aZctrvR59K1bQ',
#  '1VhD0FPDYqFhqRJVguVAJe',
#  '00drCeGE6dauNLdLcL4OEQ',
#  '6FWAIkMvnS0ABEdBKcIp5K',
#  '200DiJQhDi69nkGXOrrJgn',
#  '00Nsyeo2kcU4602zMsLWXW',
#  '4hvBK1k3eE2ACRUQKjkork',
#  '0hJfuyUwtEYMlGgvr3nzz9',
#  '0XMl0fVTh3PyPlwyJTn33n',
#  '04BNQFaBlFF7WDeTb1V0AP',
#  '0WGelFYfITJmfOnNyhRUq7',
#  '7A0xA68c4NiTvbWWAsIsoN',
#  '6Hht0SIzJwQYBkDD07Dnoj',
#  '4V1SO4C2wG9bTq6Cp7yYyA',
#  '44ufS0CWp8uO4ILi3vpinQ',
#  '4ZWyj5whGZ3nNLwOtOLrMt',
#  '5o1mS67lEoLCeFobGIaNb2',
#  '21VnSlwtvNKUFFHHKqt7fI',
#  '0oBUOlD8XPyRNmVOqkv7QA',
#  '2oGzHeApGhjANPNWYQNRQw',
#  '5UM6P3y6794GYNOzZvj2zh',
#  '1Rv6Lfdcny3Avjmpm4W4YM',
# ...

# %%
playlist = sp.user_playlist_tracks("Spotify", "7lVb3vH1Whv5rHyCOLsyYL",market = "GB")

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/7lVb3vH1Whv5rHyCOLsyYL/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2019-04-08T17:52:11Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/brendanfritt'},
#     'href': 'https://api.spotify.com/v1/users/brendanfritt',
#     'id': 'brendanfritt',
#     'type': 'user',
#     'uri': 'spotify:user:brendanfritt'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4obzFoKoKRHIphyHzJ35G3'},
#        'href': 'https://api.spotify.com/v1/artists/4obzFoKoKRHIphyHzJ35G3',
#        'id': '4obzFoKoKRHIphyHzJ35G3',
#        'name': 'Becky G',
#        'type': 'artist',
#        'uri': 'spotify:artist:4obzFoKoKRHIphyHzJ35G3'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4JlzEvVJqpb62Xwc0EmOHr'},
# ...

# %%
playlist["items"][0]
# Out:
# {'added_at': '2019-04-08T17:52:11Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/brendanfritt'},
#   'href': 'https://api.spotify.com/v1/users/brendanfritt',
#   'id': 'brendanfritt',
#   'type': 'user',
#   'uri': 'spotify:user:brendanfritt'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4obzFoKoKRHIphyHzJ35G3'},
#      'href': 'https://api.spotify.com/v1/artists/4obzFoKoKRHIphyHzJ35G3',
#      'id': '4obzFoKoKRHIphyHzJ35G3',
#      'name': 'Becky G',
#      'type': 'artist',
#      'uri': 'spotify:artist:4obzFoKoKRHIphyHzJ35G3'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4JlzEvVJqpb62Xwc0EmOHr'},
#    'href': 'https://api.spotify.com/v1/albums/4JlzEvVJqpb62Xwc0EmOHr',
#    'id': '4JlzEvVJqpb62Xwc0EmOHr',
#    'images': [{'height': 640,
# ...

# %%
import pprint

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
my_playlist1 =get_playlist_tracks('spotify','7lVb3vH1Whv5rHyCOLsyYL')

# %%
my_playlist1_id_list = []
for i in my_playlist:
    my_playlist_id_list.append(i['track']['id'])

# %%
audio_list =[]
for i in my_playlist1_id_list:
    audio_list.append(sp.audio_features(i)[0])
audio_list
# Out:
# []

# %%
my_playlist1_df = pd.DataFrame(audio_list)
my_playlist1_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
