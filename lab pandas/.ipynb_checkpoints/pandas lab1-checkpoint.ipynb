# %%
import pandas as pd

# %%
file = pd.read_csv("insurance.csv")

# %%
file
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
print(file.head)
# Out:
# <bound method NDFrame.head of      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
import pandas as pd
file = pd.read_csv("insurance.csv")
def load_original_data():
    file = pd.read_csv("insurance.csv")
    return file

# %%
hk_df= load_original_data()

# %%
def lower_case_column_names(hk_df):
    hk_df.columns=[i.lower() for i in hk_df.columns]
    return hk_df

# %%
hk_df=lower_case_column_names(hk_df)

# %%
hk_df
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
def clean_gender_values(g):
    if g in ['M','Male']:
        return 'Male'
    elif g in ['F','Femal','female']:
        return 'Female'
    else:
        return np.nan

# %%
def clean_states(x):
    if x in ['Washington','WA']:
        return 'Washington'
    elif x in ['Arizona','AZ']:
        return 'Arizona'
    elif x in ['California','Cali']:
        return 'California'

# %%
def clean_eduction(e):
    hk_df.columns = [e.replace ("Bachelors" ,"Bachelor") for e in hk_df.columns]
    return hk_df

# %%
def del_percent(v):
    hk_df.columns['customer_lifetime_value'] = hk_df['customer_lifetime_value'].str.rstrip('%')
    return hk_df

# %%
def vehicle(v):
    if v in [ "Sports Car", "Luxury SUV" , "Luxury Car" ]:
        return 'Luxury'
