# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
file1 = pd.read_csv('c2119.csv')

# %%
file2 = pd.read_csv('c2228.csv')

# %%
file1.head()
# Out:
#    Pos            Name       Value
# 0    1           China  1367485388
# 1    2           India  1251695584
# 2    3  European Union   513949445
# 3    4   United States   321368864
# 4    5       Indonesia   255993674

# %%
file2.head()
# Out:
#    Pos            Name  Value
# 0    1  American Samoa   74.6
# 1    2           Nauru   71.1
# 2    3    Cook Islands   63.7
# 3    4         Tokelau   63.4
# 4    5           Tonga   57.6

# %%
file1 = file1.sort_values('Name').drop("Pos", axis=1)

# %%
file2 = file2.sort_values('Name').drop("Pos", axis=1)

# %%
file2.head()
# Out:
#                Name  Value
# 181     Afghanistan    2.2
# 87          Albania   21.3
# 115         Algeria   16.0
# 0    American Samoa   74.6
# 57          Andorra   25.2

# %%
def rename_columns(file1):
    file1.rename(columns = {'Name':'Country','Value':'Population'},inplace = True)
    return file1

# %%
file1 = rename_columns(file1)

# %%
file1
# Out:
#             Country  Population
# 40      Afghanistan    32564342
# 136         Albania     3029278
# 33          Algeria    39542166
# 207  American Samoa       54343
# 200         Andorra       85580
# ..              ...         ...
# 141       West Bank     2785366
# 171  Western Sahara      570866
# 47            Yemen    26737317
# 69           Zambia    15066266
# 71         Zimbabwe    14229541
#
# [238 rows x 2 columns]

# %%
def rename_columns(file2):
    file2.rename(columns = {'Name':'Country','Value':'Obesity'},inplace = True)
    return file2

# %%
file2 = rename_columns(file2)

# %%
file2
# Out:
#             Country  Obesity
# 181     Afghanistan      2.2
# 87          Albania     21.3
# 115         Algeria     16.0
# 0    American Samoa     74.6
# 57          Andorra     25.2
# ..              ...      ...
# 25        Venezuela     30.3
# 185         Vietnam      1.7
# 120           Yemen     14.5
# 173          Zambia      3.6
# 142        Zimbabwe      7.0
#
# [191 rows x 2 columns]

# %%
file1.merge(file2,how = "inner", on='Country')
# Out:
#             Country  Population  Obesity
# 0       Afghanistan    32564342      2.2
# 1           Albania     3029278     21.3
# 2           Algeria    39542166     16.0
# 3    American Samoa       54343     74.6
# 4           Andorra       85580     25.2
# ..              ...         ...      ...
# 186       Venezuela    29275460     30.3
# 187         Vietnam    94348835      1.7
# 188           Yemen    26737317     14.5
# 189          Zambia    15066266      3.6
# 190        Zimbabwe    14229541      7.0
#
# [191 rows x 3 columns]

# %%
def analyze(factbook_pop, factbook_obesity):
    pop_data = pd.read_csv(factbook_pop)
    obesity_data = pd.read_csv(factbook_obesity)
    return

# %%
merged_data = file1.merge(file2,how = "inner", on='Country')

# %%
merged_data
# Out:
#             Country  Population  Obesity
# 0       Afghanistan    32564342      2.2
# 1           Albania     3029278     21.3
# 2           Algeria    39542166     16.0
# 3    American Samoa       54343     74.6
# 4           Andorra       85580     25.2
# ..              ...         ...      ...
# 186       Venezuela    29275460     30.3
# 187         Vietnam    94348835      1.7
# 188           Yemen    26737317     14.5
# 189          Zambia    15066266      3.6
# 190        Zimbabwe    14229541      7.0
#
# [191 rows x 3 columns]

# %%
 merged_data[(merged_data['Obesity'] > 20) & (merged_data['Population'] > 10000000)]
# Out:
#                 Country  Population  Obesity
# 7             Argentina    43431886     29.7
# 9             Australia    22751014     26.8
# 17              Belgium    11323973     22.1
# 33               Canada    35099836     26.2
# 36                Chile    17508260     29.4
# 46                 Cuba    11031433     21.5
# 48       Czech Republic    10644842     32.7
# 52   Dominican Republic    10478756     21.2
# 53              Ecuador    15868396     21.4
# 54                Egypt    88487396     33.1
# 66              Germany    80854408     25.1
# 68               Greece    10775643     20.1
# 81                 Iraq    37056169     27.0
# 88           Kazakhstan    18157122     23.7
# 113              Mexico   121736809     32.1
# 137              Poland    38562189     25.3
# 138            Portugal    10825309     24.0
# 141              Russia   142423773     26.5
# 148        Saudi Arabia    27752316     33.0
# 158        South Africa    53675563     31.3
# ...

# %%
filtered_data= merged_data[(merged_data['Obesity'] > 20) & (merged_data['Population'] > 10000000)]

# %%
filtered_data
# Out:
#                 Country  Population  Obesity
# 7             Argentina    43431886     29.7
# 9             Australia    22751014     26.8
# 17              Belgium    11323973     22.1
# 33               Canada    35099836     26.2
# 36                Chile    17508260     29.4
# 46                 Cuba    11031433     21.5
# 48       Czech Republic    10644842     32.7
# 52   Dominican Republic    10478756     21.2
# 53              Ecuador    15868396     21.4
# 54                Egypt    88487396     33.1
# 66              Germany    80854408     25.1
# 68               Greece    10775643     20.1
# 81                 Iraq    37056169     27.0
# 88           Kazakhstan    18157122     23.7
# 113              Mexico   121736809     32.1
# 137              Poland    38562189     25.3
# 138            Portugal    10825309     24.0
# 141              Russia   142423773     26.5
# 148        Saudi Arabia    27752316     33.0
# 158        South Africa    53675563     31.3
# ...

# %%
filtered_data.sort_values(by='Obesity', ascending=False)
# Out:
#                 Country  Population  Obesity
# 54                Egypt    88487396     33.1
# 182       United States   321368864     33.0
# 148        Saudi Arabia    27752316     33.0
# 48       Czech Republic    10644842     32.7
# 113              Mexico   121736809     32.1
# 158        South Africa    53675563     31.3
# 186           Venezuela    29275460     30.3
# 7             Argentina    43431886     29.7
# 36                Chile    17508260     29.4
# 176              Turkey    79414269     27.8
# 166               Syria    17064854     27.1
# 81                 Iraq    37056169     27.0
# 181      United Kingdom    64088222     26.9
# 9             Australia    22751014     26.8
# 159               Spain    48146134     26.6
# 141              Russia   142423773     26.5
# 33               Canada    35099836     26.2
# 137              Poland    38562189     25.3
# 66              Germany    80854408     25.1
# 138            Portugal    10825309     24.0
# ...

# %%
sorted_data = filtered_data.sort_values(by='Obesity', ascending=False)

# %%
sorted_data
# Out:
#                 Country  Population  Obesity
# 54                Egypt    88487396     33.1
# 182       United States   321368864     33.0
# 148        Saudi Arabia    27752316     33.0
# 48       Czech Republic    10644842     32.7
# 113              Mexico   121736809     32.1
# 158        South Africa    53675563     31.3
# 186           Venezuela    29275460     30.3
# 7             Argentina    43431886     29.7
# 36                Chile    17508260     29.4
# 176              Turkey    79414269     27.8
# 166               Syria    17064854     27.1
# 81                 Iraq    37056169     27.0
# 181      United Kingdom    64088222     26.9
# 9             Australia    22751014     26.8
# 159               Spain    48146134     26.6
# 141              Russia   142423773     26.5
# 33               Canada    35099836     26.2
# 137              Poland    38562189     25.3
# 66              Germany    80854408     25.1
# 138            Portugal    10825309     24.0
# ...

# %%
sorted_data.head(10)
# Out:
#             Country  Population  Obesity
# 54            Egypt    88487396     33.1
# 182   United States   321368864     33.0
# 148    Saudi Arabia    27752316     33.0
# 48   Czech Republic    10644842     32.7
# 113          Mexico   121736809     32.1
# 158    South Africa    53675563     31.3
# 186       Venezuela    29275460     30.3
# 7         Argentina    43431886     29.7
# 36            Chile    17508260     29.4
# 176          Turkey    79414269     27.8

# %%
 top_10_countries = sorted_data.head(10)

# %%
 top_10_countries.index = range(1,11)

# %%
 top_10_countries.columns = ['Country', 'Population', 'Obesity Rate']

# %%
 top_10_countries
# Out:
#            Country  Population  Obesity Rate
# 1            Egypt    88487396          33.1
# 2    United States   321368864          33.0
# 3     Saudi Arabia    27752316          33.0
# 4   Czech Republic    10644842          32.7
# 5           Mexico   121736809          32.1
# 6     South Africa    53675563          31.3
# 7        Venezuela    29275460          30.3
# 8        Argentina    43431886          29.7
# 9            Chile    17508260          29.4
# 10          Turkey    79414269          27.8

# %%
analyze('c2119.csv',"c2228.csv")
